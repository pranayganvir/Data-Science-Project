# %% [markdown]
# ### What is Data Visualization?
#
# Data Visualization is the process of representing data in graphical or pictorial form. Instead of working with raw numbers or large datasets, visualization helps present insights in a way that is easy to understand, interpret, and communicate.
#
# It acts as a bridge between data and decision-making, allowing us to quickly spot patterns, trends, outliers, and relationships.

# %% [markdown]
# ### Types of Data Visualization Techniques
#
# - Univariate plots (showing one variable): Histogram, Pie Chart, Bar Chart.
# - Bivariate plots (two variables): Scatter Plot, Box Plot, Line Plot.
# - Multivariate plots (three or more variables): Heatmap, Pair Plot, Stacked Bar Plot.
# - Advanced/Interactive: Word Clouds, Sankey Diagrams, Geographic Maps, 3D Plots.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#Load the dataset
df = pd.read_csv('student.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# ### 1 Line Plot
#
# A line plot is a graph that displays data points connected by straight lines, typically used to show trends or changes over time. It helps in visualizing patterns, increases, decreases, and overall movement in data.

# %%
l1 = [10, 20, 30, 40, 50, 60, 50, 30, 90, 100]
plt.plot(l1)
plt.title('Basic Line Plot')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# ### 2 Histogram
#
# A histogram is a type of bar graph that shows the frequency distribution of a numerical variable by dividing the data into intervals (bins) and displaying how many values fall into each bin.

# %%
plt.hist(df['math score'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Math Mark')
plt.xlabel('Marks Range')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 3 Bar Graph
#
# A bar plot is used to represent categorical data with rectangular bars.
# - Each bar’s length/height shows the frequency or value of the category.
# - Useful for comparing different groups or categories.

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
sns.barplot(x='gender', y = 'math score', data=df, palette='Set1', hue='gender')
plt.show()

# %%
sns.barplot(x='parental level of education', y = 'reading score', data=df, palette='Set1', hue='gender')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='race/ethnicity', y = 'writing score', data=df, palette='Set1', hue='gender', legend=False)
plt.show()

# %%
level = np.array([1,2,3,4,5])
salary = np.array([50, 400, 250, 100, 500])

# %%
df2 = pd.DataFrame(level, columns=['Level'])

# %%
df2['Salary'] = salary

# %%
df2
# Out:
#    Level  Salary
# 0      1      50
# 1      2     400
# 2      3     250
# 3      4     100
# 4      5     500

# %% [markdown]
# ### 4 Scatter Plot
# A scatter plot is used to visualize the relationship between two continuous variables.
# - Each point represents an observation.
# - It helps identify patterns, correlations, clusters, and outliers.
# - Often used in regression and trend analysis.

# %%
sns.scatterplot(x='Level',y='Salary', data=df2)
plt.show()

# %% [markdown]
# ### 5 Pie Chart
# A pie chart is a circular chart divided into slices to illustrate numerical proportions.
#
# - Each slice shows the relative size of a category compared to the whole.
# - Best for showing percentage or part-to-whole relationships.
# - Not ideal when there are too many categories (hard to read).

# %%
# Data
labels = ["Math", "Science", "English", "History", "Art"]
scores = [85, 90, 78, 88, 70]

# Create pie chart
plt.pie(scores, labels=labels, autopct="%1.1f%%", startangle=140, colors=sns.color_palette('pastel'))
plt.title("Pie Chart of Subject Scores")
plt.show()

# %%
tips = sns.load_dataset("tips")

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %% [markdown]
# ### 6 Distplot

# %%
sns.distplot(tips['total_bill'])
plt.show()
# Out:
# C:\Users\LOQ\AppData\Local\Temp\ipykernel_16780\1769337044.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])

# %%
sns.histplot(tips['total_bill'])
plt.show()

# %% [markdown]
# ### 7 JointPlot
#
# A JointPlot in Seaborn is used to visualize the relationship between two variables along with their individual distributions.
#
# - It combines a scatter plot (or other plot types) in the center with histograms (or KDE plots) on the margins.
#
# - Helps you understand both correlation and distribution at the same time.

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, palette='Set1')
plt.show()

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')
plt.show()

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')
plt.show()

# %% [markdown]
# ### 8 Pair Plot
#
# A pair plot is a grid of scatter plots and histograms that shows the relationships between multiple variables in a dataset.
#
# - Scatter plots → for relationships between two variables.
#
# - Histograms / KDE plots → for the distribution of each variable on the diagonal.
#
# - Great for exploratory data analysis (EDA) to quickly spot trends, correlations, and clusters.

# %%
sns.pairplot(tips,hue='sex')
plt.show()

# %%
sns.pairplot(tips,hue='sex',palette='RdGy_r')
plt.show()

# %%
sns.pairplot(tips,hue='day',palette='tab20')
plt.show()

# %% [markdown]
# ### 9 Box Plot
#
# A Box Plot (or Whisker Plot) is used to show the distribution of numerical data through five summary statistics:
#
# - Minimum
#
# - First Quartile (Q1)
#
# - Median (Q2)
#
# - Third Quartile (Q3)
#
# - Maximum
#
# It also shows outliers (points that fall outside the whiskers).
#
# Useful for detecting spread, skewness, and outliers in the data.

# %%
sns.boxplot(x='day',y='total_bill',data=tips, palette='Set2')
plt.show()

# %% [markdown]
# ### 10 Violin Plot
#
# A violin plot is used to visualize the distribution of numerical data across different categories.
#
# - It combines a box plot (summary statistics like median, quartiles) and a kernel density plot (probability distribution).
#
# - The width of the violin shows the density of the data at different values.
#
# - Useful for comparing distributions between categories.

# %%
sns.violinplot(x='day',y='total_bill',data=tips, palette='Set1')
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',data=tips, palette='Set1', jitter=True)
plt.show()

# %%
sns.swarmplot(x='day',y='total_bill',data=tips, palette='Set1')
plt.show()
